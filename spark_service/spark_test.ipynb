# %%
# importing relevant modules 
import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
# imporing relevant modules required to ingest data into kafka_broker
from pyspark.storagelevel import StorageLevel
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, TimestampType

# %%
spark = SparkSession.builder \
    .appName("Jupyter Notebook") \
    .master("spark://localhost:7077") \
    .config("spark.executor.memory", "1g") \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memoryOverhead", "256m") \
    .getOrCreate()

# %%
print(f"Connected to: {spark.sparkContext.master}")
print(f"Spark version: {spark.version}")

# %%
df = spark.read.parquet("/tmp/data/green_taxi/green_tripdata_2025-01.parquet")

# %%
print(f"Total rows: {df.count()}")

# %%
top_10 = df.limit(10)
top_10.show(truncate=False)

# %%
top_10 = df.limit(10)
top_10.show(truncate=False)

# Save
top_10.write.mode("overwrite").csv("/tmp/data/green_taxi/output.csv", header=True)

# Stop session when done
spark.stop()
